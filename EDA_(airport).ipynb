# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv('airport.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 337 non-null    int64
#  1   ident              337 non-null    object
#  2   type               337 non-null    object
#  3   name               337 non-null    object
#  4   latitude_deg       337 non-null    float64
#  5   longitude_deg      337 non-null    float64
#  6   elevation_ft       262 non-null    float64
#  7   iso_region         337 non-null    object
#  8   municipality       170 non-null    object
#  9   scheduled_service  337 non-null    int64
#  10  gps_code           232 non-null    object
#  11  iata_code          132 non-null    object
#  12  local_code         58 non-null     object
#  13  year_built         89 non-null     float64
#  14  year_tier          89 non-null     float64
#  15  Closed             337 non-null    object
# ...

# %%
df.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft  \
# count     337.000000    337.000000     337.000000    262.000000
# mean    62662.946588     22.826837      80.861196   1448.362595
# std     94991.519843      6.128305       8.189304   2454.905728
# min      3283.000000      0.000000       0.000000      5.000000
# 25%     26457.000000     19.719444      75.845596    310.250000
# 50%     26578.000000     23.631500      78.971497    760.000000
# 75%     46481.000000     26.888700      86.706944   1684.750000
# max    325010.000000     35.500000      97.019661  22000.000000
#
#        scheduled_service   year_built    year_tier         score
# count         337.000000    89.000000    89.000000  3.370000e+02
# mean            0.249258  1962.033708  1968.494382  3.685760e+03
# std             0.433227    27.391708    22.777642  5.543450e+04
# min             0.000000  1910.000000  1950.000000  0.000000e+00
# ...

# %%
df.isnull().sum()
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# latitude_deg           0
# longitude_deg          0
# elevation_ft          75
# iso_region             0
# municipality         167
# scheduled_service      0
# gps_code             105
# iata_code            205
# local_code           279
# year_built           248
# year_tier            248
# Closed                 0
# home_link            293
# wikipedia_link       203
# keywords             246
# score                  0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# id                    0.000000
# ident                 0.000000
# type                  0.000000
# name                  0.000000
# latitude_deg          0.000000
# longitude_deg         0.000000
# elevation_ft         22.255193
# iso_region            0.000000
# municipality         49.554896
# scheduled_service     0.000000
# gps_code             31.157270
# iata_code            60.830861
# local_code           82.789318
# year_built           73.590504
# year_tier            73.590504
# Closed                0.000000
# home_link            86.943620
# wikipedia_link       60.237389
# keywords             72.997033
# score                 0.000000
# dtype: float64

# %%
df.drop(columns=['home_link','local_code'],inplace=True)

# %%
df.head()
# Out:
#       id ident           type                                       name  \
# 0  26555  VIDP  large_airport        Indira Gandhi International Airport
# 1  26434  VABB  large_airport  Chhatrapati Shivaji International Airport
# 2  26618  VOMM  large_airport              Chennai International Airport
# 3  35145  VOBL  large_airport           Kempegowda International Airport
# 4  26444  VAGO  large_airport                  Goa International Airport
#
#    latitude_deg  longitude_deg  elevation_ft iso_region   municipality  \
# 0     28.566500      77.103104         777.0      IN-DL      New Delhi
# 1     19.088699      72.867897          39.0      IN-MM         Mumbai
# 2     12.990005      80.169296          52.0      IN-TN        Chennai
# 3     13.197900      77.706299        3000.0      IN-KA      Bangalore
# 4     15.380800      73.831398         150.0      IN-GA  Vasco da Gama
#
#    scheduled_service gps_code iata_code  year_built  year_tier Closed  \
# ...

# %%
df['keywords'].fillna(df['keywords'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# latitude_deg           0
# longitude_deg          0
# elevation_ft          75
# iso_region             0
# municipality         167
# scheduled_service      0
# gps_code             105
# iata_code            205
# local_code           279
# year_built           248
# year_tier            248
# Closed                 0
# home_link            293
# wikipedia_link       203
# keywords               0
# score                  0
# dtype: int64

# %%
df['wikipedia_link'].fillna(df['wikipedia_link'].mode()[0],inplace=True)

# %%
df['year_tier'].fillna(df['year_tier'].mode()[0],inplace=True)

# %%
df['year_built'].fillna(df['year_built'].mode()[0],inplace=True)

# %%
df['iata_code'].fillna(df['iata_code'].mode()[0],inplace=True)

# %%
df['gps_code'].fillna(df['gps_code'].mode()[0],inplace=True)

# %%
df['municipality'].fillna(df['municipality'].mode()[0],inplace=True)

# %%
df['elevation_ft'].fillna(df['elevation_ft'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# latitude_deg           0
# longitude_deg          0
# elevation_ft           0
# iso_region             0
# municipality           0
# scheduled_service      0
# gps_code               0
# iata_code              0
# local_code           279
# year_built             0
# year_tier              0
# Closed                 0
# home_link            293
# wikipedia_link         0
# keywords               0
# score                  0
# dtype: int64

# %%
df.drop(columns=['home_link','local_code'],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                   0
# ident                0
# type                 0
# name                 0
# latitude_deg         0
# longitude_deg        0
# elevation_ft         0
# iso_region           0
# municipality         0
# scheduled_service    0
# gps_code             0
# iata_code            0
# year_built           0
# year_tier            0
# Closed               0
# wikipedia_link       0
# keywords             0
# score                0
# dtype: int64

# %%
df.tail()
# Out:
#          id    ident           type                              name  \
# 332   46625  IN-0062  small_airport                   Shirpur Airport
# 333   46640  IN-0064  small_airport                  Umaria Air Field
# 334   46561  IN-0038       heliport  Upper Tadong Indian Army Helipad
# 335  319166  IN-0101  small_airport                Vanasthali Airport
# 336   46557  IN-0034  small_airport               Vijay Nagar Airport
#
#      latitude_deg  longitude_deg  elevation_ft iso_region  municipality  \
# 332     21.323999      74.956734          16.0      IN-MM       Shirpur
# 333     23.532514      80.808220        1510.0      IN-MP        Umaria
# 334     27.306717      88.599650          16.0      IN-SK  Upper Tadong
# 335     26.407627      75.870128          16.0      IN-RJ    Vanasthali
# 336     19.884100      73.840567          16.0      IN-MM   Vijay Nagar
#
#      scheduled_service gps_code iata_code  year_built  year_tier Closed  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['elevation_ft','year_built','year_tier']]=df[['elevation_ft','year_built','year_tier']].astype(int)

# %%
df
# Out:
#          id    ident           type  \
# 0     26555     VIDP  large_airport
# 1     26434     VABB  large_airport
# 2     26618     VOMM  large_airport
# 3     35145     VOBL  large_airport
# 4     26444     VAGO  large_airport
# ..      ...      ...            ...
# 332   46625  IN-0062  small_airport
# 333   46640  IN-0064  small_airport
# 334   46561  IN-0038       heliport
# 335  319166  IN-0101  small_airport
# 336   46557  IN-0034  small_airport
#
#                                           name  latitude_deg  longitude_deg  \
# 0          Indira Gandhi International Airport     28.566500      77.103104
# 1    Chhatrapati Shivaji International Airport     19.088699      72.867897
# 2                Chennai International Airport     12.990005      80.169296
# 3             Kempegowda International Airport     13.197900      77.706299
# 4                    Goa International Airport     15.380800      73.831398
# ...

# %%
import seaborn as sns

# %%
sns.catplot(data=df,x='type',y='elevation_ft',kind='box',aspect=2)
plt.title('box plot of population and ocean proximity')
plt.show()
# Out:
# c:\Program Files\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
value_column='elevation_ft'
outliers=df[(df[value_column]<df[value_column].mean() -3 * df[value_column].std()) | (df[value_column]>df[value_column].mean() + 3 * df[value_column].std())]
print("outliers:\n")
outliers
# Out:
# outliers:
#         id    ident            type                                     name  \
# 49   26569     VILH  medium_airport      Leh Kushok Bakula Rimpochee Airport
# 150   3317     VE67   small_airport          Machuka Advanced Landing Ground
# 163   3325     VI57   small_airport                           Thoise Airport
# 164   3327     VI65   small_airport                           Kargil Airport
# 165   3328     VI66   small_airport           Fukche Advanced Landing Ground
# 167  42716  IN-0003   small_airport  Daulat Beg Oldi Advanced Landing Ground
# 239  35130  IN-0002        heliport                 Tawang Air Force Station
# 240  35129  IN-0001        heliport              Siachen Glacier AFS Airport
# 254  42717  IN-0004        heliport                              Leh Helipad
#
#      latitude_deg  longitude_deg  elevation_ft iso_region municipality  \
# 49      34.135899      77.546501         10682      IN-JK          Leh
# ...
